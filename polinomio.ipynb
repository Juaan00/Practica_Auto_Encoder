# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
x=[1,2,3,4,5]

y_1=[5,10]

y_2=[6,3,10]

x = np.array(x)

y_1 = np.array(y_1)

y_2 = np.array(y_2)

plt.plot(x[:2],y_1, 'o', label='line 1')
plt.plot(x[:3],y_2, 'o', label='line 2')
plt.show()
